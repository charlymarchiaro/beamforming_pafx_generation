# %%
import os.path
from common.consts import PATTERN_FILE_FORMAT__MSI, PATTERN_TYPE__BROADCAST, PATTERN_TYPE__BEAMFORMING_ELEMENT
from common.beamforming_antenna_generator import BeamformingAntennaGenerator
from common.re_filter import ReFilter
from common.pattern_name_param_extractor import PatternNameParamExtractor
from common.pattern_payload_param_extractor import PatternPayloadParamExtractor
from common.pattern_name_param_selector import PatternNameParamSelector

# %%
generator = BeamformingAntennaGenerator({
    # General parameters
    'src_folder': 'D:\\Cell Planning\\Antenna model processing\\Library\\mMIMO\\mMIMO Antennas\\Nokia\\AQQN',
    'pattern_file_format': PATTERN_FILE_FORMAT__MSI,
    'version': '7.4',
    'filename': '(script)_AQQN_64T64R.pafx',
    'name': 'AQQN 64T 192 AE mMIMO 3.5TDD',
    'type': 'Cellular',
    'comment': 'AQQN 64T 192 AE mMIMO 3.5TDD',
    'manufacturer': 'Nokia',
    'cost': 0,
    'cost_unit': 'USD',
    'length_cm': 100.1,
    'width_cm': 44.8,
    'depth_cm': 11.3,
    'weight_kg': 36,
    'wind_load_factor': 587,
    'supp_elec_tilt': True,
    'supp_elec_azimuth': False,
    'supp_elec_beamwidth': False,
    'cont_adj_elec_tilt': False,
    
    # Source file filter
    'src_file_re_filter': ReFilter(
        allow=['.*BeamPattern V0\.5.*Optimized.*Envelope.*\.msi$'],
        deny=['.*TypeApproval.*', '.*3GPP.*'],
    ),
    
    # Parameter extractors
    'pattern_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='(?P<cg>.+)\..{3}$',
    ),
    'scenario_extractor': PatternNameParamExtractor(
        extract_re='.*\\\\BeamPattern\\\\(?P<cg>BeamSets.+?)\\\\.*',
    ),
    'v_port_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='(?P<cg>.+)-Envelope.*',
    ),
    'pattern_type_extractor': PatternNameParamExtractor(
        path_part='basename',
        pre_capture_proc=lambda r: r.lower(),
        post_capture_proc=lambda r: PATTERN_TYPE__BROADCAST if 'ssb' in r else PATTERN_TYPE__BEAMFORMING_ELEMENT,
    ),
    'center_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY'])
    ),
    'min_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY']) - 100
    ),
    'max_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY']) + 100
    ),
    'electrical_tilt_extractor': PatternNameParamExtractor(
        extract_re='.*etilt\_offset=(?P<cg>-?\d+)°.*',
        pre_capture_proc=lambda r: r.lower(),
        post_capture_proc=lambda r: int(r),
    ),
    'polarization_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 'Vertical',
    ),
    'polarization_type_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: None,
    ),
    'v_port_number_of_ports_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4,
    ),
    'horiz_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4,
    ),
    'horiz_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4.3,
    ),
    'vert_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 8,
    ),
    'vert_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 17.7,
    ),
    
    # Parameter selectors
    'scenario_selector': None,
    'v_port_name_selector': None,
})

# %%
extracted_tags = generator.list_extracted_tags(detailed=False)
# Out:
# ===============================================================
# Extracted tags list
# ===============================================================
#
# [scenario]:
#    1.  BeamSets5GC000533_Optimized#1_Az90Az120..........4 items
#    2.  BeamSets5GC000533_Optimized#2#2#2#2_Az90Az120....4 items
#    3.  BeamSets5GC000533_Optimized#2#2_Az90Az120........4 items
#    4.  BeamSets5GC000533_Optimized#2_Az90Az120..........4 items
#    5.  BeamSets5GC000533_Optimized#3#1_Az90Az120........4 items
#    6.  BeamSets5GC000533_Optimized#3#3#2b_Az90Az120.....4 items
#    7.  BeamSets5GC000533_Optimized#3#3#2_Az90Az120......4 items
#    8.  BeamSets5GC000533_Optimized#3#3_Az90Az120........4 items
#    9.  BeamSets5GC000533_Optimized#4#2_Az90Az120........4 items
#   10.  BeamSets5GC000533_Optimized#4#4_Az90Az120........4 items
#   11.  BeamSets5GC000533_Optimized#4_Az90Az120..........4 items
#   12.  BeamSets5GC000533_Optimized#5#1_Az90Az120........4 items
#   13.  BeamSets5GC000533_Optimized#5#3_Az90Az120........4 items
#   14.  BeamSets5GC000533_Optimized#6#2_Az90Az120........4 items
#   15.  BeamSets5GC000533_Optimized#6_Az90Az120..........4 items
#   16.  BeamSets5GC000533_Optimized#8_Az90Az120..........4 items
#
# [v_port_name]:
#    1.  AQQN-Optimized-120degAzOp-p00-ap06-#1.........2 items
#    2.  AQQN-Optimized-90degAzOp-p00-ap06-#1..........2 items
#    3.  AQQN-Optimized-40degAzOp-p00-ap06-#2#2#2#2....2 items
#    4.  AQQN-Optimized-90degAzOp-p00-ap06-#2#2#2#2....2 items
#    5.  AQQN-Optimized-120degAzOp-p00-ap06-#2#2.......2 items
#    6.  AQQN-Optimized-90degAzOp-p00-ap06-#2#2........2 items
#    7.  AQQN-Optimized-120degAzOp-p00-ap06-#2.........2 items
#    8.  AQQN-Optimized-90degAzOp-p00-ap06-#2..........2 items
#    9.  AQQN-Optimized-120degAzOp-p00-ap06-#3#1.......2 items
#   10.  AQQN-Optimized-90degAzOp-p00-ap06-#3#1........2 items
#   11.  AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2b....2 items
#   12.  AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2b.....2 items
#   13.  AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2.....2 items
#   14.  AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2......2 items
#   15.  AQQN-Optimized-120degAzOp-p00-ap06-#3#3.......2 items
#   16.  AQQN-Optimized-90degAzOp-p00-ap06-#3#3........2 items
#   17.  AQQN-Optimized-120degAzOp-p00-ap06-#4#2.......2 items
#   18.  AQQN-Optimized-90degAzOp-p00-ap06-#4#2........2 items
#   19.  AQQN-Optimized-120degAzOp-p00-ap06-#4#4.......2 items
#   20.  AQQN-Optimized-90degAzOp-p00-ap06-#4#4........2 items
#   21.  AQQN-Optimized-120degAzOp-p00-ap06-#4.........2 items
#   22.  AQQN-Optimized-90degAzOp-p00-ap06-#4..........2 items
#   23.  AQQN-Optimized-120degAzOp-p00-ap06-#5#1.......2 items
#   24.  AQQN-Optimized-90degAzOp-p00-ap06-#5#1........2 items
#   25.  AQQN-Optimized-120degAzOp-p00-ap06-#5#3.......2 items
#   26.  AQQN-Optimized-90degAzOp-p00-ap06-#5#3........2 items
#   27.  AQQN-Optimized-120degAzOp-p00-ap06-#6#2.......2 items
#   28.  AQQN-Optimized-90degAzOp-p00-ap06-#6#2........2 items
#   29.  AQQN-Optimized-120degAzOp-p00-ap06-#6.........2 items
#   30.  AQQN-Optimized-90degAzOp-p00-ap06-#6..........2 items
#   31.  AQQN-Optimized-120degAzOp-p00-ap06-#8.........2 items
#   32.  AQQN-Optimized-90degAzOp-p00-ap06-#8..........2 items
#
# [pattern_type]:
#   1.  broadcast...............32 items
#   2.  beamforming_element.....32 items
#
# [freq_band]:
#   1.  3400-3600...............64 items
#
# [electrical_tilt]:
#   1.  0.......................64 items
#
# [polarization]:
#   1.  Vertical................64 items
#
# [polarization_type]:
#   1.  None....................64 items
#
# [v_port_number_of_ports]:
#   1.  4.......................64 items
#
# [horiz_number_of_elements]:
#   1.  4.......................64 items
#
# [horiz_sep_dist_cm]:
#   1.  4.3.....................64 items
#
# [vert_number_of_elements]:
#   1.  8.......................64 items
#
# [vert_sep_dist_cm]:
#   1.  17.7....................64 items

# %%
generator.generate(os.path.abspath('.\output'))
# Out:
# ===============================================================
# Scenario > Virutal port > Virutal band > Pattern assignments
# ===============================================================
# {
#   "BeamSets5GC000533_Optimized#1_Az90Az120": {
#     "uid": "2",
#     "name": "BeamSets5GC000533_Optimized#1_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#1": {
#         "uid": "3",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#1",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#1-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#1": {
#         "uid": "4",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#1",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#1-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#2#2#2#2_Az90Az120": {
#     "uid": "5",
#     "name": "BeamSets5GC000533_Optimized#2#2#2#2_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-40degAzOp-p00-ap06-#2#2#2#2": {
#         "uid": "6",
#         "name": "AQQN-Optimized-40degAzOp-p00-ap06-#2#2#2#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-40degAzOp-p00-ap06-#2#2#2#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-40degAzOp-p00-ap06-#2#2#2#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#2#2#2#2": {
#         "uid": "7",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#2#2#2#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#2#2#2#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#2#2#2#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#2#2_Az90Az120": {
#     "uid": "8",
#     "name": "BeamSets5GC000533_Optimized#2#2_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#2#2": {
#         "uid": "9",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#2#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#2#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#2#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#2#2": {
#         "uid": "10",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#2#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#2#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#2#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#2_Az90Az120": {
#     "uid": "11",
#     "name": "BeamSets5GC000533_Optimized#2_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#2": {
#         "uid": "12",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#2": {
#         "uid": "13",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#3#1_Az90Az120": {
#     "uid": "14",
#     "name": "BeamSets5GC000533_Optimized#3#1_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#3#1": {
#         "uid": "15",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#3#1",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#1-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#3#1": {
#         "uid": "16",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#3#1",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#1-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#3#3#2b_Az90Az120": {
#     "uid": "17",
#     "name": "BeamSets5GC000533_Optimized#3#3#2b_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2b": {
#         "uid": "18",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2b",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2b-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2b-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2b": {
#         "uid": "19",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2b",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2b-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2b-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#3#3#2_Az90Az120": {
#     "uid": "20",
#     "name": "BeamSets5GC000533_Optimized#3#3#2_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2": {
#         "uid": "21",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#3#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2": {
#         "uid": "22",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#3#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#3#3_Az90Az120": {
#     "uid": "23",
#     "name": "BeamSets5GC000533_Optimized#3#3_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#3#3": {
#         "uid": "24",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#3#3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#3-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#3#3-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#3#3": {
#         "uid": "25",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#3#3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#3-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#3#3-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#4#2_Az90Az120": {
#     "uid": "26",
#     "name": "BeamSets5GC000533_Optimized#4#2_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#4#2": {
#         "uid": "27",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#4#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#4#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#4#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#4#2": {
#         "uid": "28",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#4#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#4#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#4#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#4#4_Az90Az120": {
#     "uid": "29",
#     "name": "BeamSets5GC000533_Optimized#4#4_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#4#4": {
#         "uid": "30",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#4#4",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#4#4-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#4#4-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#4#4": {
#         "uid": "31",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#4#4",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#4#4-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#4#4-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#4_Az90Az120": {
#     "uid": "32",
#     "name": "BeamSets5GC000533_Optimized#4_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#4": {
#         "uid": "33",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#4",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#4-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#4-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#4": {
#         "uid": "34",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#4",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#4-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#4-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#5#1_Az90Az120": {
#     "uid": "35",
#     "name": "BeamSets5GC000533_Optimized#5#1_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#5#1": {
#         "uid": "36",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#5#1",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#5#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#5#1-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#5#1": {
#         "uid": "37",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#5#1",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#5#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#5#1-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#5#3_Az90Az120": {
#     "uid": "38",
#     "name": "BeamSets5GC000533_Optimized#5#3_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#5#3": {
#         "uid": "39",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#5#3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#5#3-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#5#3-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#5#3": {
#         "uid": "40",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#5#3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#5#3-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#5#3-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#6#2_Az90Az120": {
#     "uid": "41",
#     "name": "BeamSets5GC000533_Optimized#6#2_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#6#2": {
#         "uid": "42",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#6#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#6#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#6#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#6#2": {
#         "uid": "43",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#6#2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#6#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#6#2-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#6_Az90Az120": {
#     "uid": "44",
#     "name": "BeamSets5GC000533_Optimized#6_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#6": {
#         "uid": "45",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#6",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#6-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#6-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#6": {
#         "uid": "46",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#6",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#6-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#6-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "BeamSets5GC000533_Optimized#8_Az90Az120": {
#     "uid": "47",
#     "name": "BeamSets5GC000533_Optimized#8_Az90Az120",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "AQQN-Optimized-120degAzOp-p00-ap06-#8": {
#         "uid": "48",
#         "name": "AQQN-Optimized-120degAzOp-p00-ap06-#8",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#8-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-120degAzOp-p00-ap06-#8-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       },
#       "AQQN-Optimized-90degAzOp-p00-ap06-#8": {
#         "uid": "49",
#         "name": "AQQN-Optimized-90degAzOp-p00-ap06-#8",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#8-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AQQN-Optimized-90degAzOp-p00-ap06-#8-Envelope_L1"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   }
# }
#
# ===============================================================
# The .pafx file was generated successfully
# --> (script)_AQQN_64T64R.pafx
# ===============================================================
