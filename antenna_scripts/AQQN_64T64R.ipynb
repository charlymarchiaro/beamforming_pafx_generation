# %%
import os.path
import re

from common.consts import PATTERN_FILE_FORMAT__MSI, PATTERN_TYPE__BROADCAST, PATTERN_TYPE__BEAMFORMING_ELEMENT, PATTERN_TYPE__BEAMSWITCHING_SERVICE
from common.beamforming_antenna_generator import BeamformingAntennaGenerator
from common.re_filter import ReFilter
from common.pattern_name_param_extractor import PatternNameParamExtractor
from common.pattern_payload_param_extractor import PatternPayloadParamExtractor
from common.pattern_name_param_selector import PatternNameParamSelector

# %%
generator = BeamformingAntennaGenerator({
    # General parameters
    'src_folder': r'D:\Cell Planning\Antenna model processing\Library\mMIMO\mMIMO Antennas\Nokia\AQQN Full_eTilt_Offset',
    'pattern_file_format': PATTERN_FILE_FORMAT__MSI,
    'version': '7.4',
    'filename': 'AQQN_64T64R.pafx',
    'name': 'AQQN 64T 192 AE mMIMO 3.5TDD',
    'type': 'Cellular',
    'comment': 'AQQN 64T 192 AE mMIMO 3.5TDD',
    'manufacturer': 'Nokia',
    'cost': 0,
    'cost_unit': 'USD',
    'length_cm': 100.1,
    'width_cm': 44.8,
    'depth_cm': 11.3,
    'weight_kg': 36,
    'wind_load_factor': 587,
    'supp_elec_tilt': True,
    'supp_elec_azimuth': False,
    'supp_elec_beamwidth': False,
    'cont_adj_elec_tilt': False,
    
    # Source file filter
    'src_file_re_filter': ReFilter(
        allow=[
            '.*Optimized.*(SSB|RefBeam|SsbBeam).*\.msi$',
        ],
        deny=[
            '.*TypeApproval.*',
            '.*3GPP.*',
            '.*PatternEnvelope.*',
        ],
    ),
    
    # Parameter extractors
    'pattern_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='(?P<cg>.+)\..{3}$',
    ),
    'scenario_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='.*-(?P<cg>\d+deg.+)-(Envelope|RefBeam|SsbBeam).*',
        post_capture_proc=lambda r: re.sub('-(p|n)\d+-a(p|n)\d+-', '-', r),
    ),
    'v_port_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='.*-(?P<cg>\d+deg.+)-(Envelope|RefBeam|SsbBeam).*',
        post_capture_proc=lambda r: re.sub('-(p|n)\d+-a(p|n)\d+-', '-', r),
    ),
    'pattern_type_extractor': PatternNameParamExtractor(
        path_part='basename',
        pre_capture_proc=lambda r: r.lower(),
        post_capture_proc=lambda r: PATTERN_TYPE__BROADCAST if 'envelope' in r else PATTERN_TYPE__BEAMSWITCHING_SERVICE,
    ),
    'center_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(float(payload.header['FREQUENCY']))
    ),
    'min_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(float(payload.header['FREQUENCY']) - 100)
    ),
    'max_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(float(payload.header['FREQUENCY']) + 100)
    ),
    'electrical_tilt_extractor': PatternNameParamExtractor(
        path_part='basename',
        pre_capture_proc=lambda r: r.lower(),
        extract_re='.*-(?P<cg>(p|n)\d+)-.*',
        post_capture_proc=lambda r: int(r.replace('p', '').replace('n', '-')),
    ),
    'polarization_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 'Vertical',
    ),
    'polarization_type_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: None,
    ),
    'v_port_number_of_ports_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 1,
    ),
    'horiz_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4,
    ),
    'horiz_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4.3,
    ),
    'vert_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 8,
    ),
    'vert_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 17.7,
    ),
    'beamswitching_service_name_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 'PDSCH' if 'RefBeam' in r else 'SSB' if 'SsbBeam' in r else 'None',
    ),
    'beamswitching_horiz_angle_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: payload.horiz_pap_pattern.get_boresight_deg(),
    ),
    'beamswitching_vert_angle_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: payload.vert_pap_pattern.get_boresight_deg(),
    ),
    
    # Parameter selectors
    'scenario_selector': None,
    'v_port_name_selector': None,
})

# %%
extracted_tags = generator.list_extracted_tags(detailed=False)
# Out:
# ===============================================================
# Extracted tags list
# ===============================================================
#
# [scenario]:
#    1.  120degAzOp-#1...........90 items
#    2.  120degAzOp-#2...........165 items
#    3.  120degAzOp-#2#2.........273 items
#    4.  120degAzOp-#3#1.........273 items
#    5.  120degAzOp-#3#3.........403 items
#    6.  120degAzOp-#3#3#2.......328 items
#    7.  120degAzOp-#3#3#2b......328 items
#    8.  120degAzOp-#4...........315 items
#    9.  120degAzOp-#4#2.........403 items
#   10.  120degAzOp-#4#4.........533 items
#   11.  120degAzOp-#5#1.........403 items
#   12.  120degAzOp-#5#3.........533 items
#   13.  120degAzOp-#6...........465 items
#   14.  120degAzOp-#6#2.........533 items
#   15.  120degAzOp-#8...........615 items
#   16.  40degAzOp-#2#2#2#2......41 items
#   17.  90degAzOp-#1............90 items
#   18.  90degAzOp-#2............165 items
#   19.  90degAzOp-#2#2..........273 items
#   20.  90degAzOp-#2#2#2#2......41 items
#   21.  90degAzOp-#3#1..........273 items
#   22.  90degAzOp-#3#3..........403 items
#   23.  90degAzOp-#3#3#2........328 items
#   24.  90degAzOp-#3#3#2b.......328 items
#   25.  90degAzOp-#4............315 items
#   26.  90degAzOp-#4#2..........403 items
#   27.  90degAzOp-#4#4..........533 items
#   28.  90degAzOp-#5#1..........403 items
#   29.  90degAzOp-#5#3..........533 items
#   30.  90degAzOp-#6............465 items
#   31.  90degAzOp-#6#2..........533 items
#   32.  90degAzOp-#8............615 items
#
# [v_port_name]:
#    1.  120degAzOp-#1...........90 items
#    2.  120degAzOp-#2...........165 items
#    3.  120degAzOp-#2#2.........273 items
#    4.  120degAzOp-#3#1.........273 items
#    5.  120degAzOp-#3#3.........403 items
#    6.  120degAzOp-#3#3#2.......328 items
#    7.  120degAzOp-#3#3#2b......328 items
#    8.  120degAzOp-#4...........315 items
#    9.  120degAzOp-#4#2.........403 items
#   10.  120degAzOp-#4#4.........533 items
#   11.  120degAzOp-#5#1.........403 items
#   12.  120degAzOp-#5#3.........533 items
#   13.  120degAzOp-#6...........465 items
#   14.  120degAzOp-#6#2.........533 items
#   15.  120degAzOp-#8...........615 items
#   16.  40degAzOp-#2#2#2#2......41 items
#   17.  90degAzOp-#1............90 items
#   18.  90degAzOp-#2............165 items
#   19.  90degAzOp-#2#2..........273 items
#   20.  90degAzOp-#2#2#2#2......41 items
#   21.  90degAzOp-#3#1..........273 items
#   22.  90degAzOp-#3#3..........403 items
#   23.  90degAzOp-#3#3#2........328 items
#   24.  90degAzOp-#3#3#2b.......328 items
#   25.  90degAzOp-#4............315 items
#   26.  90degAzOp-#4#2..........403 items
#   27.  90degAzOp-#4#4..........533 items
#   28.  90degAzOp-#5#1..........403 items
#   29.  90degAzOp-#5#3..........533 items
#   30.  90degAzOp-#6............465 items
#   31.  90degAzOp-#6#2..........533 items
#   32.  90degAzOp-#8............615 items
#
# [pattern_type]:
#   1.  beamswitching_service....11010 items
#   2.  broadcast................392 items
#
# [freq_band]:
#   1.  3400-3600...............11402 items
#
# [electrical_tilt]:
#    1.  -7......................900 items
#    2.  -6......................900 items
#    3.  -5......................900 items
#    4.  -4......................900 items
#    5.  -3......................900 items
#    6.  -2......................900 items
#    7.  -1......................900 items
#    8.  0.......................982 items
#    9.  1.......................736 items
#   10.  2.......................736 items
#   11.  3.......................736 items
#   12.  4.......................736 items
#   13.  5.......................736 items
#   14.  6.......................220 items
#   15.  7.......................220 items
#
# [polarization]:
#   1.  Vertical................11402 items
#
# [polarization_type]:
#   1.  None....................11402 items
#
# [v_port_number_of_ports]:
#   1.  1.......................11402 items
#
# [horiz_number_of_elements]:
#   1.  4.......................11402 items
#
# [horiz_sep_dist_cm]:
#   1.  4.3.....................11402 items
#
# [vert_number_of_elements]:
#   1.  8.......................11402 items
#
# [vert_sep_dist_cm]:
#   1.  17.7....................11402 items
#
# [beamswitching_service_name]:
#   1.  None....................392 items
#   2.  PDSCH...................8808 items
#   3.  SSB.....................2202 items
#
# [beamswitching_horiz_angle]:
#     1.  -53.0...................9 items
#     2.  -52.9...................17 items
#     3.  -52.7...................4 items
#     4.  -51.4...................87 items
#     5.  -51.3...................13 items
#     6.  -51.2...................11 items
#     7.  -50.1...................14 items
#     8.  -50.0...................36 items
#     9.  -49.9...................2 items
#    10.  -48.4...................52 items
#    11.  -48.2...................28 items
#    12.  -48.1...................40 items
#    13.  -48.0...................37 items
#    14.  -45.7...................10 items
#    15.  -45.6...................3 items
#    16.  -45.5...................4 items
#    17.  -45.4...................5 items
#    18.  -45.2...................26 items
#    19.  -45.1...................2 items
#    20.  -44.9...................6 items
#    21.  -44.8...................6 items
#    22.  -44.7...................8 items
#    23.  -44.6...................16 items
#    24.  -44.0...................26 items
#    25.  -43.7...................4 items
#    26.  -43.2...................2 items
#    27.  -43.1...................2 items
#    28.  -43.0...................4 items
#    29.  -42.7...................2 items
#    30.  -42.4...................4 items
#    31.  -42.3...................12 items
#    32.  -40.8...................19 items
#    33.  -40.7...................7 items
#    34.  -40.6...................4 items
#    35.  -39.8...................101 items
#    36.  -39.7...................116 items
#    37.  -39.6...................22 items
#    38.  -39.3...................4 items
#    39.  -39.2...................4 items
#    40.  -39.1...................47 items
#    41.  -39.0...................16 items
#    42.  -38.9...................8 items
#    43.  -38.8...................44 items
#    44.  -38.7...................12 items
#    45.  -38.5...................13 items
#    46.  -38.4...................20 items
#    47.  -38.3...................15 items
#    48.  -38.0...................18 items
#    49.  -37.9...................12 items
#    50.  -37.7...................4 items
#    51.  -37.5...................80 items
#    52.  -37.4...................40 items
#    53.  -37.3...................33 items
#    54.  -36.8...................18 items
#    55.  -36.7...................24 items
#    56.  -36.5...................10 items
#    57.  -36.1...................12 items
#    58.  -35.9...................14 items
#    59.  -35.8...................4 items
#    60.  -35.7...................42 items
#    61.  -35.6...................3 items
#    62.  -35.4...................32 items
#    63.  -35.3...................9 items
#    64.  -34.7...................15 items
#    65.  -34.6...................7 items
#    66.  -34.4...................4 items
#    67.  -34.3...................4 items
#    68.  -33.9...................26 items
#    69.  -32.3...................99 items
#    70.  -32.1...................21 items
#    71.  -32.0...................37 items
#    72.  -31.8...................50 items
#    73.  -31.7...................112 items
#    74.  -31.6...................13 items
#    75.  -31.4...................35 items
#    76.  -31.3...................26 items
#    77.  -31.0...................38 items
#    78.  -30.9...................23 items
#    79.  -30.2...................17 items
#    80.  -30.1...................12 items
#    81.  -30.0...................16 items
#    82.  -29.9...................100 items
#    83.  -29.8...................11 items
#    84.  -29.7...................23 items
#    85.  -29.6...................16 items
#    86.  -29.3...................52 items
#    87.  -28.8...................11 items
#    88.  -28.7...................5 items
#    89.  -28.6...................25 items
#    90.  -28.5...................19 items
#    91.  -26.8...................17 items
#    92.  -26.7...................12 items
#    93.  -26.6...................26 items
#    94.  -26.5...................17 items
#    95.  -26.3...................12 items
#    96.  -25.9...................115 items
#    97.  -25.8...................1 items
#    98.  -25.6...................41 items
#    99.  -25.5...................10 items
#   100.  -25.4...................45 items
#   101.  -25.3...................59 items
#   102.  -25.2...................24 items
#   103.  -24.2...................7 items
#   104.  -24.0...................92 items
#   105.  -23.9...................12 items
#   106.  -23.2...................3 items
#   107.  -23.0...................27 items
#   108.  -22.0...................11 items
#   109.  -21.9...................19 items
#   110.  -20.9...................101 items
#   111.  -20.8...................10 items
#   112.  -20.7...................68 items
#   113.  -20.6...................25 items
#   114.  -20.4...................75 items
#   115.  -20.2...................4 items
#   116.  -20.0...................2 items
#   117.  -19.9...................8 items
#   118.  -19.8...................12 items
#   119.  -18.8...................157 items
#   120.  -17.9...................20 items
#   121.  -17.8...................53 items
#   122.  -17.5...................40 items
#   123.  -17.4...................33 items
#   124.  -17.3...................25 items
#   125.  -17.0...................59 items
#   126.  -16.9...................111 items
#   127.  -16.3...................12 items
#   128.  -16.1...................14 items
#   129.  -15.5...................26 items
#   130.  -15.4...................4 items
#   131.  -15.3...................42 items
#   132.  -15.1...................82 items
#   133.  -15.0...................33 items
#   134.  -14.9...................52 items
#   135.  -14.8...................6 items
#   136.  -14.6...................2 items
#   137.  -12.5...................30 items
#   138.  -12.4...................111 items
#   139.  -12.3...................22 items
#   140.  -12.1...................12 items
#   141.  -12.0...................72 items
#   142.  -10.2...................43 items
#   143.  -10.1...................5 items
#   144.  -10.0...................186 items
#   145.  -9.9....................64 items
#   146.  -9.8....................3 items
#   147.  -9.6....................46 items
#   148.  -9.3....................108 items
#   149.  -8.3....................27 items
#   150.  -8.1....................52 items
#   151.  -8.0....................7 items
#   152.  -7.5....................30 items
#   153.  -6.6....................86 items
#   154.  -6.3....................118 items
#   155.  -6.1....................39 items
#   156.  -5.2....................56 items
#   157.  -5.0....................101 items
#   158.  -4.9....................17 items
#   159.  -4.7....................43 items
#   160.  -4.3....................92 items
#   161.  -4.2....................32 items
#   162.  -4.0....................39 items
#   163.  -3.4....................111 items
#   164.  -3.3....................14 items
#   165.  -3.2....................8 items
#   166.  -3.0....................8 items
#   167.  -2.5....................30 items
#   168.  -0.0....................694 items
#   169.  2.5.....................30 items
#   170.  3.0.....................8 items
#   171.  3.2.....................8 items
#   172.  3.3.....................14 items
#   173.  3.4.....................111 items
#   174.  4.0.....................39 items
#   175.  4.2.....................32 items
#   176.  4.3.....................92 items
#   177.  4.7.....................43 items
#   178.  4.9.....................17 items
#   179.  5.0.....................101 items
#   180.  5.2.....................56 items
#   181.  6.1.....................39 items
#   182.  6.3.....................118 items
#   183.  6.6.....................86 items
#   184.  7.5.....................30 items
#   185.  8.0.....................7 items
#   186.  8.1.....................52 items
#   187.  8.3.....................27 items
#   188.  9.3.....................108 items
#   189.  9.6.....................46 items
#   190.  9.8.....................3 items
#   191.  9.9.....................64 items
#   192.  10.0....................186 items
#   193.  10.1....................5 items
#   194.  10.2....................43 items
#   195.  12.0....................72 items
#   196.  12.1....................12 items
#   197.  12.3....................22 items
#   198.  12.4....................111 items
#   199.  12.5....................30 items
#   200.  14.6....................2 items
#   201.  14.8....................6 items
#   202.  14.9....................52 items
#   203.  15.0....................33 items
#   204.  15.1....................82 items
#   205.  15.3....................42 items
#   206.  15.4....................4 items
#   207.  15.5....................26 items
#   208.  16.1....................14 items
#   209.  16.3....................12 items
#   210.  16.9....................111 items
#   211.  17.0....................59 items
#   212.  17.3....................25 items
#   213.  17.4....................33 items
#   214.  17.5....................40 items
#   215.  17.8....................53 items
#   216.  17.9....................20 items
#   217.  18.8....................157 items
#   218.  19.8....................12 items
#   219.  19.9....................8 items
#   220.  20.0....................2 items
#   221.  20.2....................4 items
#   222.  20.4....................75 items
#   223.  20.6....................25 items
#   224.  20.7....................68 items
#   225.  20.8....................10 items
#   226.  20.9....................101 items
#   227.  21.9....................19 items
#   228.  22.0....................11 items
#   229.  23.0....................27 items
#   230.  23.2....................3 items
#   231.  23.9....................12 items
#   232.  24.0....................92 items
#   233.  24.2....................7 items
#   234.  25.2....................24 items
#   235.  25.3....................59 items
#   236.  25.4....................45 items
#   237.  25.5....................10 items
#   238.  25.6....................41 items
#   239.  25.8....................1 items
#   240.  25.9....................115 items
#   241.  26.3....................12 items
#   242.  26.5....................17 items
#   243.  26.6....................26 items
#   244.  26.7....................12 items
#   245.  26.8....................17 items
#   246.  28.5....................19 items
#   247.  28.6....................25 items
#   248.  28.7....................5 items
#   249.  28.8....................11 items
#   250.  29.3....................52 items
#   251.  29.6....................16 items
#   252.  29.7....................23 items
#   253.  29.8....................11 items
#   254.  29.9....................100 items
#   255.  30.0....................16 items
#   256.  30.1....................12 items
#   257.  30.2....................17 items
#   258.  30.9....................23 items
#   259.  31.0....................38 items
#   260.  31.3....................26 items
#   261.  31.4....................35 items
#   262.  31.6....................13 items
#   263.  31.7....................112 items
#   264.  31.8....................50 items
#   265.  32.0....................37 items
#   266.  32.1....................21 items
#   267.  32.3....................99 items
#   268.  33.9....................26 items
#   269.  34.3....................4 items
#   270.  34.4....................4 items
#   271.  34.6....................7 items
#   272.  34.7....................15 items
#   273.  35.3....................9 items
#   274.  35.4....................32 items
#   275.  35.6....................3 items
#   276.  35.7....................42 items
#   277.  35.8....................4 items
#   278.  35.9....................14 items
#   279.  36.1....................12 items
#   280.  36.5....................10 items
#   281.  36.7....................24 items
#   282.  36.8....................18 items
#   283.  37.3....................33 items
#   284.  37.4....................40 items
#   285.  37.5....................80 items
#   286.  37.7....................4 items
#   287.  37.9....................12 items
#   288.  38.0....................18 items
#   289.  38.3....................15 items
#   290.  38.4....................20 items
#   291.  38.5....................13 items
#   292.  38.7....................12 items
#   293.  38.8....................44 items
#   294.  38.9....................8 items
#   295.  39.0....................16 items
#   296.  39.1....................47 items
#   297.  39.2....................4 items
#   298.  39.3....................4 items
#   299.  39.6....................22 items
#   300.  39.7....................116 items
#   301.  39.8....................101 items
#   302.  40.6....................4 items
#   303.  40.7....................7 items
#   304.  40.8....................19 items
#   305.  42.3....................12 items
#   306.  42.4....................4 items
#   307.  42.7....................2 items
#   308.  43.0....................4 items
#   309.  43.1....................2 items
#   310.  43.2....................2 items
#   311.  43.7....................4 items
#   312.  44.0....................26 items
#   313.  44.6....................16 items
#   314.  44.7....................8 items
#   315.  44.8....................6 items
#   316.  44.9....................6 items
#   317.  45.1....................2 items
#   318.  45.2....................26 items
#   319.  45.4....................5 items
#   320.  45.5....................4 items
#   321.  45.6....................3 items
#   322.  45.7....................10 items
#   323.  48.0....................37 items
#   324.  48.1....................40 items
#   325.  48.2....................28 items
#   326.  48.4....................52 items
#   327.  49.9....................2 items
#   328.  50.0....................36 items
#   329.  50.1....................14 items
#   330.  51.2....................11 items
#   331.  51.3....................13 items
#   332.  51.4....................87 items
#   333.  52.7....................4 items
#   334.  52.9....................17 items
#   335.  53.0....................9 items
#
# [beamswitching_vert_angle]:
#     1.  -2.9....................188 items
#     2.  -2.5....................12 items
#     3.  -1.9....................188 items
#     4.  -1.5....................12 items
#     5.  -1.0....................188 items
#     6.  -0.6....................215 items
#     7.  -0.4....................12 items
#     8.  -0.0....................189 items
#     9.  0.4.....................208 items
#    10.  0.5.....................4 items
#    11.  0.6.....................12 items
#    12.  1.0.....................188 items
#    13.  1.3.....................220 items
#    14.  1.5.....................188 items
#    15.  1.7.....................184 items
#    16.  1.8.....................1 items
#    17.  2.0.....................37 items
#    18.  2.3.....................208 items
#    19.  2.4.....................1 items
#    20.  2.5.....................188 items
#    21.  2.7.....................188 items
#    22.  2.8.....................1 items
#    23.  2.9.....................8 items
#    24.  3.0.....................8 items
#    25.  3.1.....................244 items
#    26.  3.3.....................1 items
#    27.  3.4.....................1 items
#    28.  3.5.....................189 items
#    29.  3.6.....................86 items
#    30.  3.7.....................146 items
#    31.  3.9.....................1 items
#    32.  4.0.....................222 items
#    33.  4.1.....................1 items
#    34.  4.2.....................1 items
#    35.  4.3.....................5 items
#    36.  4.4.....................212 items
#    37.  4.5.....................25 items
#    38.  4.6.....................126 items
#    39.  4.7.....................2 items
#    40.  4.9.....................1 items
#    41.  5.0.....................307 items
#    42.  5.2.....................2 items
#    43.  5.3.....................14 items
#    44.  5.4.....................208 items
#    45.  5.5.....................37 items
#    46.  5.6.....................121 items
#    47.  5.7.....................13 items
#    48.  5.8.....................3 items
#    49.  5.9.....................1 items
#    50.  6.0.....................365 items
#    51.  6.2.....................1 items
#    52.  6.3.....................53 items
#    53.  6.4.....................233 items
#    54.  6.5.....................123 items
#    55.  6.6.....................68 items
#    56.  6.7.....................1 items
#    57.  6.8.....................1 items
#    58.  6.9.....................318 items
#    59.  7.0.....................43 items
#    60.  7.2.....................6 items
#    61.  7.3.....................183 items
#    62.  7.4.....................44 items
#    63.  7.5.....................203 items
#    64.  7.6.....................41 items
#    65.  7.7.....................357 items
#    66.  7.9.....................1 items
#    67.  8.2.....................3 items
#    68.  8.3.....................221 items
#    69.  8.4.....................92 items
#    70.  8.5.....................12 items
#    71.  8.6.....................45 items
#    72.  8.7.....................561 items
#    73.  8.8.....................6 items
#    74.  8.9.....................4 items
#    75.  9.0.....................82 items
#    76.  9.2.....................6 items
#    77.  9.3.....................134 items
#    78.  9.4.....................144 items
#    79.  9.5.....................4 items
#    80.  9.6.....................356 items
#    81.  9.7.....................8 items
#    82.  9.9.....................1 items
#    83.  10.0....................286 items
#    84.  10.2....................1 items
#    85.  10.3....................76 items
#    86.  10.4....................24 items
#    87.  10.5....................28 items
#    88.  10.6....................497 items
#    89.  10.7....................4 items
#    90.  10.8....................1 items
#    91.  10.9....................18 items
#    92.  11.0....................124 items
#    93.  11.1....................6 items
#    94.  11.2....................4 items
#    95.  11.3....................84 items
#    96.  11.4....................104 items
#    97.  11.5....................60 items
#    98.  11.6....................144 items
#    99.  11.7....................18 items
#   100.  11.9....................62 items
#   101.  12.0....................58 items
#   102.  12.2....................12 items
#   103.  12.3....................6 items
#   104.  12.5....................1448 items

# %%
generator.generate(os.path.abspath('.\output'))
# Out:
# ===============================================================
# Scenario > Virutal port > Virutal band > Pattern assignments
# ===============================================================
# {
#   "120degAzOp-#1": {
#     "uid": "2",
#     "name": "120degAzOp-#1",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "120degAzOp-#1": {
#         "uid": "3",
#         "name": "120degAzOp-#1",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-n01-ap05-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n02-ap04-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n03-ap03-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n04-ap02-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n05-ap01-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n06-ap00-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n07-an01-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p00-ap06-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p01-ap07-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p02-ap08-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p03-ap09-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p04-ap10-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p05-ap11-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p06-ap12-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p07-ap13-#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": -20.39517,
#                   "vert_angle": 2.69585,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.39287,
#                   "vert_angle": 2.69051,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.6914,
#                   "vert_angle": 7.29381,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.70577,
#                   "vert_angle": 7.29329,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.40528,
#                   "vert_angle": 1.69749,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40814,
#                   "vert_angle": 1.70404,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.70066,
#                   "vert_angle": 6.40145,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.70244,
#                   "vert_angle": 6.40556,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.40214,
#                   "vert_angle": 1.00204,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40825,
#                   "vert_angle": 1.00456,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.40868,
#                   "vert_angle": 5.39597,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40017,
#                   "vert_angle": 5.39331,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.39666,
#                   "vert_angle": 0.00313,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.39465,
#                   "vert_angle": 0.00189,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.39216,
#                   "vert_angle": 4.39122,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.401,
#                   "vert_angle": 4.40275,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.39511,
#                   "vert_angle": -1.0041,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40023,
#                   "vert_angle": -1.00722,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.39322,
#                   "vert_angle": 3.49701,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40708,
#                   "vert_angle": 3.50942,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.39122,
#                   "vert_angle": -1.90793,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.39848,
#                   "vert_angle": -1.90004,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.40539,
#                   "vert_angle": 2.49536,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.39929,
#                   "vert_angle": 2.50674,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.39993,
#                   "vert_angle": -2.90602,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n07-an01-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.39905,
#                   "vert_angle": -2.89519,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n07-an01-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.40818,
#                   "vert_angle": 1.49159,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n07-an01-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.4085,
#                   "vert_angle": 1.50557,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n07-an01-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.3903,
#                   "vert_angle": 3.69147,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p00-ap06-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40558,
#                   "vert_angle": 3.70079,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p00-ap06-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.70659,
#                   "vert_angle": 8.30205,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p00-ap06-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.7045,
#                   "vert_angle": 8.30781,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p00-ap06-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.4021,
#                   "vert_angle": 4.59752,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p01-ap07-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.40754,
#                   "vert_angle": 4.60949,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p01-ap07-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.69962,
#                   "vert_angle": 9.29859,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p01-ap07-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.70997,
#                   "vert_angle": 9.30821,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p01-ap07-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.69585,
#                   "vert_angle": 5.60464,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p02-ap08-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.69969,
#                   "vert_angle": 5.59967,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p02-ap08-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.70367,
#                   "vert_angle": 9.99881,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p02-ap08-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.69176,
#                   "vert_angle": 9.99662,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p02-ap08-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.70014,
#                   "vert_angle": 6.50382,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p03-ap09-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.70889,
#                   "vert_angle": 6.50383,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p03-ap09-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.6008,
#                   "vert_angle": 11.00382,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p03-ap09-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.59877,
#                   "vert_angle": 10.99194,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p03-ap09-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.70131,
#                   "vert_angle": 7.4961,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p04-ap10-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.69744,
#                   "vert_angle": 7.50118,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p04-ap10-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.59339,
#                   "vert_angle": 11.99226,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p04-ap10-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.60513,
#                   "vert_angle": 12.00251,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p04-ap10-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.70097,
#                   "vert_angle": 8.70325,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p05-ap11-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.69828,
#                   "vert_angle": 8.69983,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p05-ap11-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.60771,
#                   "vert_angle": 12.49091,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p05-ap11-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.59026,
#                   "vert_angle": 12.49931,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p05-ap11-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.60863,
#                   "vert_angle": 10.599,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p06-ap12-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.59566,
#                   "vert_angle": 10.59429,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p06-ap12-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.59439,
#                   "vert_angle": 12.49866,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p06-ap12-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.59562,
#                   "vert_angle": 12.49265,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p06-ap12-#1-RefBeam-0010_L0"
#                 },
#                 {
#                   "horiz_angle": -20.60766,
#                   "vert_angle": 12.49916,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p07-ap13-#1-RefBeam-0007_L0"
#                 },
#                 {
#                   "horiz_angle": 20.5947,
#                   "vert_angle": 12.50798,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p07-ap13-#1-RefBeam-0008_L0"
#                 },
#                 {
#                   "horiz_angle": -20.60232,
#                   "vert_angle": 12.50393,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p07-ap13-#1-RefBeam-0009_L0"
#                 },
#                 {
#                   "horiz_angle": 20.59174,
#                   "vert_angle": 12.49877,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p07-ap13-#1-RefBeam-0010_L0"
#                 }
#               ],
#               "SSB": [
#                 {
#                   "horiz_angle": -0.00199,
#                   "vert_angle": 5.00041,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00708,
#                   "vert_angle": 3.99248,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00419,
#                   "vert_angle": 3.09065,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00501,
#                   "vert_angle": 2.29177,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00837,
#                   "vert_angle": 1.29702,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00323,
#                   "vert_angle": 0.39775,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00955,
#                   "vert_angle": -0.60934,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n07-an01-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00559,
#                   "vert_angle": 6.00162,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p00-ap06-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00524,
#                   "vert_angle": 6.99935,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p01-ap07-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00981,
#                   "vert_angle": 7.69856,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p02-ap08-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00988,
#                   "vert_angle": 8.69932,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p03-ap09-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00773,
#                   "vert_angle": 9.60723,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p04-ap10-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00141,
#                   "vert_angle": 10.60219,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p05-ap11-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00282,
#                   "vert_angle": 11.5958,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p06-ap12-#1-SsbBeam-0006_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00413,
#                   "vert_angle": 12.50376,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-p07-ap13-#1-SsbBeam-0006_L0"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "90degAzOp-#1": {
#     "uid": "4",
#     "name": "90degAzOp-#1",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "90degAzOp-#1": {
#         "uid": "5",
#         "name": "90degAzOp-#1",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-90degAzOp-n01-ap05-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-n02-ap04-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-n03-ap03-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-n04-ap02-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-n05-ap01-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-n06-ap00-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-n07-an01-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p00-ap06-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p01-ap07-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p02-ap08-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p03-ap09-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p04-ap10-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p05-ap11-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p06-ap12-#1-Envelope_L1-SSB",
#               "AQQN-Optimized-90degAzOp-p07-ap13-#1-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": -16.99115,
#                   "vert_angle": 2.70391,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n01-ap05-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00278,
#                   "vert_angle": 2.70606,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n01-ap05-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00321,
#                   "vert_angle": 7.30475,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n01-ap05-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99593,
#                   "vert_angle": 7.29752,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n01-ap05-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00736,
#                   "vert_angle": 1.69964,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n02-ap04-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99154,
#                   "vert_angle": 1.69702,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n02-ap04-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00527,
#                   "vert_angle": 6.40292,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n02-ap04-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99054,
#                   "vert_angle": 6.40612,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n02-ap04-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00003,
#                   "vert_angle": 1.00687,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n03-ap03-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.0037,
#                   "vert_angle": 1.00268,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n03-ap03-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00851,
#                   "vert_angle": 5.39378,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n03-ap03-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99161,
#                   "vert_angle": 5.39292,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n03-ap03-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -16.99913,
#                   "vert_angle": -0.00704,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n04-ap02-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99895,
#                   "vert_angle": -0.0043,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n04-ap02-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00412,
#                   "vert_angle": 4.40511,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n04-ap02-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99592,
#                   "vert_angle": 4.40648,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n04-ap02-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00302,
#                   "vert_angle": -0.99422,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n05-ap01-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00059,
#                   "vert_angle": -1.00923,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n05-ap01-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -16.99292,
#                   "vert_angle": 3.50452,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n05-ap01-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99685,
#                   "vert_angle": 3.50667,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n05-ap01-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -16.99662,
#                   "vert_angle": -1.90404,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99125,
#                   "vert_angle": -1.90668,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.0091,
#                   "vert_angle": 2.49629,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00904,
#                   "vert_angle": 2.50748,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00698,
#                   "vert_angle": -2.90839,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99303,
#                   "vert_angle": -2.90506,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -16.99138,
#                   "vert_angle": 1.49851,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99661,
#                   "vert_angle": 1.5044,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -16.99219,
#                   "vert_angle": 3.69075,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99384,
#                   "vert_angle": 3.6917,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00087,
#                   "vert_angle": 8.29768,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00004,
#                   "vert_angle": 8.30002,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00846,
#                   "vert_angle": 4.60228,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00881,
#                   "vert_angle": 4.59316,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.0008,
#                   "vert_angle": 9.29453,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00729,
#                   "vert_angle": 9.29539,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00634,
#                   "vert_angle": 5.59534,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00862,
#                   "vert_angle": 5.59269,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.30317,
#                   "vert_angle": 9.99093,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.29346,
#                   "vert_angle": 10.00331,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00693,
#                   "vert_angle": 6.50473,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99742,
#                   "vert_angle": 6.49871,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.30055,
#                   "vert_angle": 10.99016,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.29994,
#                   "vert_angle": 11.00635,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00516,
#                   "vert_angle": 7.50138,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 16.99065,
#                   "vert_angle": 7.50551,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.3968,
#                   "vert_angle": 12.00229,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.39323,
#                   "vert_angle": 11.99167,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.00564,
#                   "vert_angle": 8.70313,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.00471,
#                   "vert_angle": 8.69541,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.3901,
#                   "vert_angle": 12.50416,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.3906,
#                   "vert_angle": 12.50094,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.29292,
#                   "vert_angle": 10.60514,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.29464,
#                   "vert_angle": 10.59924,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.40935,
#                   "vert_angle": 12.4953,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.40074,
#                   "vert_angle": 12.49112,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#1-RefBeam-0005_L0"
#                 },
#                 {
#                   "horiz_angle": -17.39002,
#                   "vert_angle": 12.50698,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#1-RefBeam-0002_L0"
#                 },
#                 {
#                   "horiz_angle": 17.39435,
#                   "vert_angle": 12.50961,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#1-RefBeam-0003_L0"
#                 },
#                 {
#                   "horiz_angle": -17.39632,
#                   "vert_angle": 12.50068,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#1-RefBeam-0004_L0"
#                 },
#                 {
#                   "horiz_angle": 17.40218,
#                   "vert_angle": 12.50302,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#1-RefBeam-0005_L0"
#                 }
#               ],
#               "SSB": [
#                 {
#                   "horiz_angle": -0.00116,
#                   "vert_angle": 4.99002,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n01-ap05-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00227,
#                   "vert_angle": 4.00061,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n02-ap04-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00908,
#                   "vert_angle": 3.0993,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n03-ap03-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": 0.0055,
#                   "vert_angle": 2.30737,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n04-ap02-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.0033,
#                   "vert_angle": 1.30596,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n05-ap01-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00303,
#                   "vert_angle": 0.3921,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00895,
#                   "vert_angle": -0.60676,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00486,
#                   "vert_angle": 5.99075,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00091,
#                   "vert_angle": 6.99242,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00435,
#                   "vert_angle": 7.70479,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00242,
#                   "vert_angle": 8.70809,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00937,
#                   "vert_angle": 9.591,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.00902,
#                   "vert_angle": 10.59699,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": -0.0031,
#                   "vert_angle": 11.59034,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#1-SsbBeam-0001_L0"
#                 },
#                 {
#                   "horiz_angle": 0.00651,
#                   "vert_angle": 12.50623,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#1-SsbBeam-0001_L0"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "120degAzOp-#2": {
#     "uid": "6",
#     "name": "120degAzOp-#2",
#     "horiz_number_of_elements": 4,
#     "horiz_sep_dist_cm": 4.3,
#     "vert_number_of_elements": 8,
#     "vert_sep_dist_cm": 17.7,
#     "v_ports": {
#       "120degAzOp-#2": {
#         "uid": "7",
#         "name": "120degAzOp-#2",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AQQN-Optimized-120degAzOp-n01-ap05-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n02-ap04-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n03-ap03-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n04-ap02-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n05-ap01-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n06-ap00-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-n07-an01-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p00-ap06-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p01-ap07-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p02-ap08-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p03-ap09-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p04-ap10-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p05-ap11-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p06-ap12-#2-Envelope_L1-SSB",
#               "AQQN-Optimized-120degAzOp-p07-ap13-#2-Envelope_L1-SSB"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": -38.00708,
#                   "vert_angle": 2.70823,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0022_L0"
#                 },
#                 {
#                   "horiz_angle": -9.30324,
#                   "vert_angle": 2.70541,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0023_L0"
#                 },
#                 {
#                   "horiz_angle": -38.2975,
#                   "vert_angle": 7.29131,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0024_L0"
#                 },
#                 {
#                   "horiz_angle": -9.30686,
#                   "vert_angle": 7.30034,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0025_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30908,
#                   "vert_angle": 2.69824,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0027_L0"
#                 },
#                 {
#                   "horiz_angle": 37.99105,
#                   "vert_angle": 2.70069,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0028_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30877,
#                   "vert_angle": 7.29006,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0029_L0"
#                 },
#                 {
#                   "horiz_angle": 38.291,
#                   "vert_angle": 7.29447,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n01-ap05-#2-RefBeam-0030_L0"
#                 },
#                 {
#                   "horiz_angle": -37.906,
#                   "vert_angle": 1.69339,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0022_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29907,
#                   "vert_angle": 1.692,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0023_L0"
#                 },
#                 {
#                   "horiz_angle": -38.30718,
#                   "vert_angle": 6.39338,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0024_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29942,
#                   "vert_angle": 6.40186,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0025_L0"
#                 },
#                 {
#                   "horiz_angle": 9.29831,
#                   "vert_angle": 1.69094,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0027_L0"
#                 },
#                 {
#                   "horiz_angle": 37.90735,
#                   "vert_angle": 1.70638,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0028_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30884,
#                   "vert_angle": 6.39856,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0029_L0"
#                 },
#                 {
#                   "horiz_angle": 38.30274,
#                   "vert_angle": 6.40625,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n02-ap04-#2-RefBeam-0030_L0"
#                 },
#                 {
#                   "horiz_angle": -37.89301,
#                   "vert_angle": 1.00896,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0022_L0"
#                 },
#                 {
#                   "horiz_angle": -9.30688,
#                   "vert_angle": 1.00573,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0023_L0"
#                 },
#                 {
#                   "horiz_angle": -37.9963,
#                   "vert_angle": 5.39577,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0024_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29564,
#                   "vert_angle": 5.40996,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0025_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30601,
#                   "vert_angle": 0.99593,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0027_L0"
#                 },
#                 {
#                   "horiz_angle": 37.89084,
#                   "vert_angle": 1.00019,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0028_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30012,
#                   "vert_angle": 5.39578,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0029_L0"
#                 },
#                 {
#                   "horiz_angle": 37.99811,
#                   "vert_angle": 5.40332,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n03-ap03-#2-RefBeam-0030_L0"
#                 },
#                 {
#                   "horiz_angle": -37.89263,
#                   "vert_angle": 0.00593,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0022_L0"
#                 },
#                 {
#                   "horiz_angle": -9.3068,
#                   "vert_angle": 0.00872,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0023_L0"
#                 },
#                 {
#                   "horiz_angle": -38.00303,
#                   "vert_angle": 4.39324,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0024_L0"
#                 },
#                 {
#                   "horiz_angle": -9.2961,
#                   "vert_angle": 4.39664,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0025_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30884,
#                   "vert_angle": 0.0036,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0027_L0"
#                 },
#                 {
#                   "horiz_angle": 37.90485,
#                   "vert_angle": 0.00199,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0028_L0"
#                 },
#                 {
#                   "horiz_angle": 9.29632,
#                   "vert_angle": 4.40317,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0029_L0"
#                 },
#                 {
#                   "horiz_angle": 38.00504,
#                   "vert_angle": 4.40978,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n04-ap02-#2-RefBeam-0030_L0"
#                 },
#                 {
#                   "horiz_angle": -37.89854,
#                   "vert_angle": -1.00778,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0022_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29122,
#                   "vert_angle": -0.99859,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0023_L0"
#                 },
#                 {
#                   "horiz_angle": -37.99425,
#                   "vert_angle": 3.49412,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0024_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29785,
#                   "vert_angle": 3.50386,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0025_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30534,
#                   "vert_angle": -1.00011,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0027_L0"
#                 },
#                 {
#                   "horiz_angle": 37.90984,
#                   "vert_angle": -1.00025,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0028_L0"
#                 },
#                 {
#                   "horiz_angle": 9.29792,
#                   "vert_angle": 3.50658,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0029_L0"
#                 },
#                 {
#                   "horiz_angle": 38.00572,
#                   "vert_angle": 3.49215,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n05-ap01-#2-RefBeam-0030_L0"
#                 },
#                 {
#                   "horiz_angle": -37.90951,
#                   "vert_angle": -1.90283,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#2-RefBeam-0022_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29798,
#                   "vert_angle": -1.89177,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#2-RefBeam-0023_L0"
#                 },
#                 {
#                   "horiz_angle": -38.00192,
#                   "vert_angle": 2.50417,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#2-RefBeam-0024_L0"
#                 },
#                 {
#                   "horiz_angle": -9.29644,
#                   "vert_angle": 2.50184,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#2-RefBeam-0025_L0"
#                 },
#                 {
#                   "horiz_angle": 9.30508,
#                   "vert_angle": -1.9004,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#2-RefBeam-0027_L0"
#                 },
#                 {
#                   "horiz_angle": 37.8945,
#                   "vert_angle": -1.89173,
#                   "pattern_name": "AQQN-Optimized-120degAzOp-n06-ap00-#2-RefBeam-0028_L0"
#                 },
#                 {
#                   "horiz_angle": 9.29443,
#                   "vert_angle": 2.4995,
# ...
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.90377,
#                   "vert_angle": 0.40372,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.49436,
#                   "vert_angle": 0.39487,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n06-ap00-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.50833,
#                   "vert_angle": -0.59993,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.90087,
#                   "vert_angle": -0.60503,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.30324,
#                   "vert_angle": -0.6031,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -5.2064,
#                   "vert_angle": -0.60035,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 5.19333,
#                   "vert_angle": -0.59661,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.30823,
#                   "vert_angle": -0.59062,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.89023,
#                   "vert_angle": -0.59929,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.50615,
#                   "vert_angle": -0.6099,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-n07-an01-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.50295,
#                   "vert_angle": 5.99336,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.90082,
#                   "vert_angle": 6.00336,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.1065,
#                   "vert_angle": 6.00331,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -5.20265,
#                   "vert_angle": 6.00468,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 5.20252,
#                   "vert_angle": 5.99296,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09105,
#                   "vert_angle": 5.99145,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.90707,
#                   "vert_angle": 6.0035,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.49576,
#                   "vert_angle": 5.99526,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p00-ap06-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.49406,
#                   "vert_angle": 6.90153,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.89451,
#                   "vert_angle": 6.90956,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.09592,
#                   "vert_angle": 6.89508,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -5.00517,
#                   "vert_angle": 6.90296,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 4.99725,
#                   "vert_angle": 6.90675,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09323,
#                   "vert_angle": 6.90263,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.89993,
#                   "vert_angle": 6.89908,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.49702,
#                   "vert_angle": 6.89582,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p01-ap07-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.49448,
#                   "vert_angle": 7.70757,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.89742,
#                   "vert_angle": 7.70313,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.099,
#                   "vert_angle": 7.70014,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -4.99187,
#                   "vert_angle": 7.70062,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 5.00159,
#                   "vert_angle": 7.69546,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09101,
#                   "vert_angle": 7.70708,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.89826,
#                   "vert_angle": 7.69179,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.49246,
#                   "vert_angle": 7.69051,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p02-ap08-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.49456,
#                   "vert_angle": 8.70771,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.8972,
#                   "vert_angle": 8.69034,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.09714,
#                   "vert_angle": 8.6936,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -4.9965,
#                   "vert_angle": 8.70781,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 4.99696,
#                   "vert_angle": 8.70812,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09945,
#                   "vert_angle": 8.70412,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.89075,
#                   "vert_angle": 8.70718,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.49562,
#                   "vert_angle": 8.70924,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p03-ap09-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.49937,
#                   "vert_angle": 9.60614,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.89592,
#                   "vert_angle": 9.59713,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.10472,
#                   "vert_angle": 9.59915,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -5.00242,
#                   "vert_angle": 9.60695,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 4.99584,
#                   "vert_angle": 9.59581,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09226,
#                   "vert_angle": 9.60656,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.89653,
#                   "vert_angle": 9.60778,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.50766,
#                   "vert_angle": 9.59544,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p04-ap10-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.40118,
#                   "vert_angle": 10.59789,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.90236,
#                   "vert_angle": 10.59896,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.0947,
#                   "vert_angle": 10.60188,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -4.99326,
#                   "vert_angle": 10.60931,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 5.00399,
#                   "vert_angle": 10.59172,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09788,
#                   "vert_angle": 10.59592,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.89896,
#                   "vert_angle": 10.60798,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.40662,
#                   "vert_angle": 10.595,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p05-ap11-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.69731,
#                   "vert_angle": 11.49358,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.90787,
#                   "vert_angle": 11.60239,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.10097,
#                   "vert_angle": 11.60331,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -5.00411,
#                   "vert_angle": 11.60773,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 5.00367,
#                   "vert_angle": 11.59887,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 15.09544,
#                   "vert_angle": 11.5942,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.90584,
#                   "vert_angle": 11.59626,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.70594,
#                   "vert_angle": 11.50191,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p06-ap12-#8-SsbBeam-0166_L0"
#                 },
#                 {
#                   "horiz_angle": -37.2967,
#                   "vert_angle": 12.49397,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0131_L0"
#                 },
#                 {
#                   "horiz_angle": -25.59073,
#                   "vert_angle": 12.49975,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0136_L0"
#                 },
#                 {
#                   "horiz_angle": -15.00292,
#                   "vert_angle": 12.50758,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0141_L0"
#                 },
#                 {
#                   "horiz_angle": -5.0,
#                   "vert_angle": 12.49074,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0146_L0"
#                 },
#                 {
#                   "horiz_angle": 5.00998,
#                   "vert_angle": 12.49718,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0151_L0"
#                 },
#                 {
#                   "horiz_angle": 14.9982,
#                   "vert_angle": 12.50895,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0156_L0"
#                 },
#                 {
#                   "horiz_angle": 25.59778,
#                   "vert_angle": 12.50238,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0161_L0"
#                 },
#                 {
#                   "horiz_angle": 37.30719,
#                   "vert_angle": 12.49538,
#                   "pattern_name": "AQQN-Optimized-90degAzOp-p07-ap13-#8-SsbBeam-0166_L0"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   }
# }
#
# ===============================================================
# The .pafx file was generated successfully
# --> AQQN_64T64R.pafx
# ===============================================================
