# %%
import os.path
from common.consts import PATTERN_FILE_FORMAT__MSI, PATTERN_TYPE__BROADCAST, PATTERN_TYPE__BEAMFORMING_ELEMENT
from common.beamforming_antenna_generator import BeamformingAntennaGenerator
from common.re_filter import ReFilter
from common.pattern_name_param_extractor import PatternNameParamExtractor
from common.pattern_payload_param_extractor import PatternPayloadParamExtractor
from common.pattern_name_param_selector import PatternNameParamSelector

# %%
generator = BeamformingAntennaGenerator({
    # General parameters
    'src_folder': 'D:\\Cell Planning\\Antenna model processing\\Library\\mMIMO\\mMIMO Antennas\\Huawei\\AAU5645 3.5G_MSI\\AAU5645 3.5G',
    'pattern_file_format': PATTERN_FILE_FORMAT__MSI,
    'version': '7.4',
    'filename': '(script)_AAU5645.pafx',
    'name': 'AAU5645',
    'type': 'Cellular',
    'comment': 'AAU5645',
    'manufacturer': 'Huawei',
    'cost': 0,
    'cost_unit': 'USD',
    'length_cm': 0,
    'width_cm': 0,
    'depth_cm': 0,
    'weight_kg': 0,
    'wind_load_factor': 0,
    'supp_elec_tilt': True,
    'supp_elec_azimuth': False,
    'supp_elec_beamwidth': False,
    'cont_adj_elec_tilt': False,

    # Source file filter
    'src_file_re_filter': ReFilter(
        allow=['.*\.msi$'],
        deny=['.*CSI.*'],
    ),

    # Parameter extractors
    'pattern_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='(?P<cg>.+)\..{3}$',
    ),
    'scenario_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='.*(?P<cg>Scenario.+?)\..{3}$',
    ),
    'v_port_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='.*(?P<cg>Scenario.+?)\..{3}$',
    ),
    'pattern_type_extractor': PatternNameParamExtractor(
        path_part='basename',
        pre_capture_proc=lambda r: r.lower(),
        post_capture_proc=lambda r: PATTERN_TYPE__BROADCAST if 'ssb' in r else PATTERN_TYPE__BEAMFORMING_ELEMENT,
    ),
    'center_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY'])
    ),
    'min_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY']) - 100
    ),
    'max_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY']) + 100
    ),
    'electrical_tilt_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='.*\_(?P<cg>-?\d+)T\_.*',
        post_capture_proc=lambda r: int(r),
    ),
    'polarization_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 'Vertical',
    ),
    'polarization_type_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: None,
    ),
    'v_port_number_of_ports_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4,
    ),
    'horiz_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 8,
    ),
    'horiz_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4.25,
    ),
    'vert_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 12,
    ),
    'vert_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 4.25,
    ),

    # Parameter selectors
    'scenario_selector': PatternNameParamSelector(
        select_re=lambda pattern_name: '.*' if '_Traffic' in pattern_name else None
    ),
    'v_port_name_selector': PatternNameParamSelector(
        select_re=lambda pattern_name: '.*' if '_Traffic' in pattern_name else None
    ),
})
# Out:
# [NOTICE] Could not execute regular expression: .*(?P<cg>Scenario.+?)\..{3}$, pattern: AAU5645_3500_X_CO_P45_06T_Traffic.msi
# [NOTICE] Could not execute regular expression: .*(?P<cg>Scenario.+?)\..{3}$, pattern: AAU5645_3500_X_CO_P45_06T_Traffic.msi

# %%
extracted_tags = generator.list_extracted_tags(detailed=False)
# Out:
# ===============================================================
# Extracted tags list
# ===============================================================
#
# [scenario]:
#    1.  Scenario0_4to1or7to3.....17 items
#    2.  Scenario1_4to1or7to3.....17 items
#    3.  Scenario2................17 items
#    4.  Scenario3................17 items
#    5.  Scenario4................17 items
#    6.  Scenario5................17 items
#    7.  Scenario10...............11 items
#    8.  Scenario11...............11 items
#    9.  Scenario6_4to1or7to3.....11 items
#   10.  Scenario7................11 items
#   11.  Scenario8................11 items
#   12.  Scenario9_4to1or7to3.....11 items
#   13.  Scenario12_4to1or7to3....2 items
#   14.  Scenario13...............2 items
#   15.  Scenario14...............2 items
#   16.  Scenario15_4to1or7to3....2 items
#   17.  Scenario16...............2 items
#   18.  Scenario0_8to2...........17 items
#   19.  Scenario1_8to2...........17 items
#   20.  Scenario6_8to2...........11 items
#   21.  Scenario9_8to2...........11 items
#   22.  Scenario12_8to2..........2 items
#   23.  Scenario15_8to2..........2 items
#
# [v_port_name]:
#    1.  Scenario0_4to1or7to3.....17 items
#    2.  Scenario1_4to1or7to3.....17 items
#    3.  Scenario2................17 items
#    4.  Scenario3................17 items
#    5.  Scenario4................17 items
#    6.  Scenario5................17 items
#    7.  Scenario10...............11 items
#    8.  Scenario11...............11 items
#    9.  Scenario6_4to1or7to3.....11 items
#   10.  Scenario7................11 items
#   11.  Scenario8................11 items
#   12.  Scenario9_4to1or7to3.....11 items
#   13.  Scenario12_4to1or7to3....2 items
#   14.  Scenario13...............2 items
#   15.  Scenario14...............2 items
#   16.  Scenario15_4to1or7to3....2 items
#   17.  Scenario16...............2 items
#   18.  Scenario0_8to2...........17 items
#   19.  Scenario1_8to2...........17 items
#   20.  Scenario6_8to2...........11 items
#   21.  Scenario9_8to2...........11 items
#   22.  Scenario12_8to2..........2 items
#   23.  Scenario15_8to2..........2 items
#
# [pattern_type]:
#   1.  broadcast...............215 items
#   2.  beamforming_element.....1 items
#
# [freq_band]:
#   1.  3400-3600...............216 items
#
# [electrical_tilt]:
#    1.  -1......................8 items
#    2.  -2......................8 items
#    3.  0.......................16 items
#    4.  1.......................16 items
#    5.  2.......................16 items
#    6.  3.......................16 items
#    7.  4.......................16 items
#    8.  5.......................16 items
#    9.  6.......................24 items
#   10.  7.......................16 items
#   11.  8.......................16 items
#   12.  9.......................16 items
#   13.  10......................8 items
#   14.  11......................8 items
#   15.  12......................8 items
#   16.  13......................8 items
#
# [polarization]:
#   1.  Vertical................216 items
#
# [polarization_type]:
#   1.  None....................216 items
#
# [v_port_number_of_ports]:
#   1.  4.......................216 items
#
# [horiz_number_of_elements]:
#   1.  8.......................216 items
#
# [horiz_sep_dist_cm]:
#   1.  4.25....................216 items
#
# [vert_number_of_elements]:
#   1.  12......................216 items
#
# [vert_sep_dist_cm]:
#   1.  4.25....................216 items

# %%
generator.generate(os.path.abspath('.\output'))
# Out:
# ===============================================================
# Scenario > Virutal port > Virutal band > Pattern assignments
# ===============================================================
# {
#   "Scenario0_4to1or7to3": {
#     "uid": "2",
#     "name": "Scenario0_4to1or7to3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario0_4to1or7to3": {
#         "uid": "3",
#         "name": "Scenario0_4to1or7to3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario0_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario0_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario1_4to1or7to3": {
#     "uid": "4",
#     "name": "Scenario1_4to1or7to3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario1_4to1or7to3": {
#         "uid": "5",
#         "name": "Scenario1_4to1or7to3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario1_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario1_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario2": {
#     "uid": "6",
#     "name": "Scenario2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario2": {
#         "uid": "7",
#         "name": "Scenario2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario2",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario3": {
#     "uid": "8",
#     "name": "Scenario3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario3": {
#         "uid": "9",
#         "name": "Scenario3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario3",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario4": {
#     "uid": "10",
#     "name": "Scenario4",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario4": {
#         "uid": "11",
#         "name": "Scenario4",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario4",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario4"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario5": {
#     "uid": "12",
#     "name": "Scenario5",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario5": {
#         "uid": "13",
#         "name": "Scenario5",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario5",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario5"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario10": {
#     "uid": "14",
#     "name": "Scenario10",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario10": {
#         "uid": "15",
#         "name": "Scenario10",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario10",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario10"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario11": {
#     "uid": "16",
#     "name": "Scenario11",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario11": {
#         "uid": "17",
#         "name": "Scenario11",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario11",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario11"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario6_4to1or7to3": {
#     "uid": "18",
#     "name": "Scenario6_4to1or7to3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario6_4to1or7to3": {
#         "uid": "19",
#         "name": "Scenario6_4to1or7to3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario6_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario6_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario7": {
#     "uid": "20",
#     "name": "Scenario7",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario7": {
#         "uid": "21",
#         "name": "Scenario7",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario7",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario7"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario8": {
#     "uid": "22",
#     "name": "Scenario8",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario8": {
#         "uid": "23",
#         "name": "Scenario8",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario8",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario8"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario9_4to1or7to3": {
#     "uid": "24",
#     "name": "Scenario9_4to1or7to3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario9_4to1or7to3": {
#         "uid": "25",
#         "name": "Scenario9_4to1or7to3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario9_4to1or7to3",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario9_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario12_4to1or7to3": {
#     "uid": "26",
#     "name": "Scenario12_4to1or7to3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario12_4to1or7to3": {
#         "uid": "27",
#         "name": "Scenario12_4to1or7to3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario12_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario13": {
#     "uid": "28",
#     "name": "Scenario13",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario13": {
#         "uid": "29",
#         "name": "Scenario13",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario13"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario14": {
#     "uid": "30",
#     "name": "Scenario14",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario14": {
#         "uid": "31",
#         "name": "Scenario14",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario14"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario15_4to1or7to3": {
#     "uid": "32",
#     "name": "Scenario15_4to1or7to3",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario15_4to1or7to3": {
#         "uid": "33",
#         "name": "Scenario15_4to1or7to3",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario15_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario16": {
#     "uid": "34",
#     "name": "Scenario16",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario16": {
#         "uid": "35",
#         "name": "Scenario16",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario16"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario0_8to2": {
#     "uid": "36",
#     "name": "Scenario0_8to2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario0_8to2": {
#         "uid": "37",
#         "name": "Scenario0_8to2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario0_8to2",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario0_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario1_8to2": {
#     "uid": "38",
#     "name": "Scenario1_8to2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario1_8to2": {
#         "uid": "39",
#         "name": "Scenario1_8to2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_-1T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_-2T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_10T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_11T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_12T_SSB_Scenario1_8to2",
#               "AAU5645_3500_X_CO_P45_13T_SSB_Scenario1_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario6_8to2": {
#     "uid": "40",
#     "name": "Scenario6_8to2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario6_8to2": {
#         "uid": "41",
#         "name": "Scenario6_8to2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario6_8to2",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario6_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario9_8to2": {
#     "uid": "42",
#     "name": "Scenario9_8to2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario9_8to2": {
#         "uid": "43",
#         "name": "Scenario9_8to2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_00T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_01T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_02T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_03T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_04T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_05T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_07T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_08T_SSB_Scenario9_8to2",
#               "AAU5645_3500_X_CO_P45_09T_SSB_Scenario9_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario12_8to2": {
#     "uid": "44",
#     "name": "Scenario12_8to2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario12_8to2": {
#         "uid": "45",
#         "name": "Scenario12_8to2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario12_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   },
#   "Scenario15_8to2": {
#     "uid": "46",
#     "name": "Scenario15_8to2",
#     "horiz_number_of_elements": 8,
#     "horiz_sep_dist_cm": 4.25,
#     "vert_number_of_elements": 12,
#     "vert_sep_dist_cm": 4.25,
#     "v_ports": {
#       "Scenario15_8to2": {
#         "uid": "47",
#         "name": "Scenario15_8to2",
#         "number_of_ports": 4,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_SSB_Scenario15_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": false,
#             "beamforming_element_patterns": [
#               "AAU5645_3500_X_CO_P45_06T_Traffic"
#             ],
#             "beamswitching_service_patterns": []
#           }
#         }
#       }
#     },
#     "is_beamswitching": false
#   }
# }
#
# ===============================================================
# The .pafx file was generated successfully
# --> (script)_AAU5645.pafx
# ===============================================================
