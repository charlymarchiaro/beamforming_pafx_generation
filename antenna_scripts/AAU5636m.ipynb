# %%
import os.path
import re

from common.consts import PATTERN_FILE_FORMAT__MSI, PATTERN_TYPE__BROADCAST, PATTERN_TYPE__BEAMFORMING_ELEMENT, PATTERN_TYPE__BEAMSWITCHING_SERVICE
from common.beamforming_antenna_generator import BeamformingAntennaGenerator
from common.re_filter import ReFilter
from common.pattern_name_param_extractor import PatternNameParamExtractor
from common.pattern_payload_param_extractor import PatternPayloadParamExtractor
from common.pattern_name_param_selector import PatternNameParamSelector

# %%
generator = BeamformingAntennaGenerator({
    # General parameters
    'src_folder': r'D:\TP\mMIMO Antennas\Huawei\AAU5636m_MSI',
    'pattern_file_format': PATTERN_FILE_FORMAT__MSI,
    'version': '7.4',
    'filename': 'AAU5636m.pafx',
    'name': 'AAU5636m',
    'type': 'Cellular',
    'comment': 'AAU5636m',
    'manufacturer': 'Huawei',
    'cost': 0,
    'cost_unit': 'USD',
    'length_cm': 145,
    'width_cm': 40,
    'depth_cm': 18,
    'weight_kg': 30,
    'wind_load_factor': 900,
    'supp_elec_tilt': True,
    'supp_elec_azimuth': False,
    'supp_elec_beamwidth': False,
    'cont_adj_elec_tilt': False,

    # Source file filter
    'src_file_re_filter': ReFilter(
        allow=['.*\.msi$'],
        deny=['.*CSI.*'],
    ),

    # Parameter extractors
    'pattern_name_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='(?P<cg>.+)\..{3}$',
    ),
    'scenario_extractor': PatternNameParamExtractor(
        extract_re=r'.*SSB\\(?P<cg>.+?Scenario\d+).*',
        post_capture_proc=lambda r: re.sub(r'\\AAU5635M\_.+?SSB\_', '-', r),
    ),
    'v_port_name_extractor': PatternNameParamExtractor(
        extract_re=r'.*SSB\\(?P<cg>.+?Scenario\d+).*',
        post_capture_proc=lambda r: re.sub(r'\\AAU5635M\_.+?SSB\_', '-', r),
    ),
    'pattern_type_extractor': PatternNameParamExtractor(
        path_part='basename',
        pre_capture_proc=lambda r: r.lower(),
        post_capture_proc=lambda r: PATTERN_TYPE__BROADCAST if 'ssb' in r else PATTERN_TYPE__BEAMSWITCHING_SERVICE,
    ),
    'center_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY'])
    ),
    'min_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY']) - 100
    ),
    'max_freq_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: int(payload.header['FREQUENCY']) + 100
    ),
    'electrical_tilt_extractor': PatternNameParamExtractor(
        path_part='basename',
        extract_re='.*\_(?P<cg>-?\d+)T\_.*',
        post_capture_proc=lambda r: int(r),
    ),
    'polarization_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 'Vertical',
    ),
    'polarization_type_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: None,
    ),
    'v_port_number_of_ports_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 1,
    ),
    'horiz_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 16,
    ),
    'horiz_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 0.01,
    ),
    'vert_number_of_elements_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 24,
    ),
    'vert_sep_dist_cm_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 0.01,
    ),
    'beamswitching_service_name_extractor': PatternNameParamExtractor(
        post_capture_proc=lambda r: 'PDSCH' if 'Traffic' in r else 'None',
    ),
    'beamswitching_horiz_angle_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: payload.horiz_pap_pattern.get_boresight_deg(),
    ),
    'beamswitching_vert_angle_extractor': PatternPayloadParamExtractor(
        extract_fn=lambda payload: payload.vert_pap_pattern.get_boresight_deg(),
    ),

    # Parameter selectors
    'scenario_selector': PatternNameParamSelector(
        select_re=lambda pattern_name: '.*' if '_Traffic' in pattern_name else None
    ),
    'v_port_name_selector': PatternNameParamSelector(
        select_re=lambda pattern_name: '.*' if '_Traffic' in pattern_name else None
    ),
})
# Out:
# [NOTICE] Could not execute regular expression: .*SSB\\(?P<cg>.+?Scenario\d+).*, pattern: Traffic\AAU5636M_00_X_CO_P45_06T_Traffic.msi
# [NOTICE] Could not execute regular expression: .*SSB\\(?P<cg>.+?Scenario\d+).*, pattern: Traffic\AAU5636M_00_X_CO_P45_06T_Traffic.msi

# %%
extracted_tags = generator.list_extracted_tags(detailed=False)
# Out:
# ===============================================================
# Extracted tags list
# ===============================================================
#
# [scenario]:
#    1.  7to3 or 4to1-Scenario0.....17 items
#    2.  7to3 or 4to1-Scenario1.....17 items
#    3.  7to3 or 4to1-Scenario10....4 items
#    4.  7to3 or 4to1-Scenario11....4 items
#    5.  7to3 or 4to1-Scenario12....2 items
#    6.  7to3 or 4to1-Scenario13....2 items
#    7.  7to3 or 4to1-Scenario14....2 items
#    8.  7to3 or 4to1-Scenario15....2 items
#    9.  7to3 or 4to1-Scenario16....2 items
#   10.  7to3 or 4to1-Scenario2.....17 items
#   11.  7to3 or 4to1-Scenario3.....17 items
#   12.  7to3 or 4to1-Scenario4.....17 items
#   13.  7to3 or 4to1-Scenario5.....17 items
#   14.  7to3 or 4to1-Scenario6.....4 items
#   15.  7to3 or 4to1-Scenario7.....4 items
#   16.  7to3 or 4to1-Scenario8.....4 items
#   17.  7to3 or 4to1-Scenario9.....4 items
#   18.  8to2-Scenario0.............17 items
#   19.  8to2-Scenario1.............17 items
#   20.  8to2-Scenario10............4 items
#   21.  8to2-Scenario11............4 items
#   22.  8to2-Scenario12............2 items
#   23.  8to2-Scenario13............2 items
#   24.  8to2-Scenario14............2 items
#   25.  8to2-Scenario15............2 items
#   26.  8to2-Scenario16............2 items
#   27.  8to2-Scenario2.............17 items
#   28.  8to2-Scenario3.............17 items
#   29.  8to2-Scenario4.............17 items
#   30.  8to2-Scenario5.............17 items
#   31.  8to2-Scenario6.............4 items
#   32.  8to2-Scenario7.............4 items
#   33.  8to2-Scenario8.............4 items
#   34.  8to2-Scenario9.............4 items
#
# [v_port_name]:
#    1.  7to3 or 4to1-Scenario0.....17 items
#    2.  7to3 or 4to1-Scenario1.....17 items
#    3.  7to3 or 4to1-Scenario10....4 items
#    4.  7to3 or 4to1-Scenario11....4 items
#    5.  7to3 or 4to1-Scenario12....2 items
#    6.  7to3 or 4to1-Scenario13....2 items
#    7.  7to3 or 4to1-Scenario14....2 items
#    8.  7to3 or 4to1-Scenario15....2 items
#    9.  7to3 or 4to1-Scenario16....2 items
#   10.  7to3 or 4to1-Scenario2.....17 items
#   11.  7to3 or 4to1-Scenario3.....17 items
#   12.  7to3 or 4to1-Scenario4.....17 items
#   13.  7to3 or 4to1-Scenario5.....17 items
#   14.  7to3 or 4to1-Scenario6.....4 items
#   15.  7to3 or 4to1-Scenario7.....4 items
#   16.  7to3 or 4to1-Scenario8.....4 items
#   17.  7to3 or 4to1-Scenario9.....4 items
#   18.  8to2-Scenario0.............17 items
#   19.  8to2-Scenario1.............17 items
#   20.  8to2-Scenario10............4 items
#   21.  8to2-Scenario11............4 items
#   22.  8to2-Scenario12............2 items
#   23.  8to2-Scenario13............2 items
#   24.  8to2-Scenario14............2 items
#   25.  8to2-Scenario15............2 items
#   26.  8to2-Scenario16............2 items
#   27.  8to2-Scenario2.............17 items
#   28.  8to2-Scenario3.............17 items
#   29.  8to2-Scenario4.............17 items
#   30.  8to2-Scenario5.............17 items
#   31.  8to2-Scenario6.............4 items
#   32.  8to2-Scenario7.............4 items
#   33.  8to2-Scenario8.............4 items
#   34.  8to2-Scenario9.............4 items
#
# [pattern_type]:
#   1.  beamswitching_service....1 items
#   2.  broadcast................238 items
#
# [freq_band]:
#   1.  3400-3600...............239 items
#
# [electrical_tilt]:
#    1.  -2......................12 items
#    2.  -1......................12 items
#    3.  0.......................22 items
#    4.  1.......................12 items
#    5.  2.......................12 items
#    6.  3.......................24 items
#    7.  4.......................12 items
#    8.  5.......................12 items
#    9.  6.......................25 items
#   10.  7.......................12 items
#   11.  8.......................12 items
#   12.  9.......................24 items
#   13.  10......................12 items
#   14.  11......................12 items
#   15.  12......................12 items
#   16.  13......................12 items
#
# [polarization]:
#   1.  Vertical................239 items
#
# [polarization_type]:
#   1.  None....................239 items
#
# [v_port_number_of_ports]:
#   1.  1.......................239 items
#
# [horiz_number_of_elements]:
#   1.  16......................239 items
#
# [horiz_sep_dist_cm]:
#   1.  0.01....................239 items
#
# [vert_number_of_elements]:
#   1.  24......................239 items
#
# [vert_sep_dist_cm]:
#   1.  0.01....................239 items
#
# [beamswitching_service_name]:
#   1.  None....................238 items
#   2.  PDSCH...................1 items
#
# [beamswitching_horiz_angle]:
#    1.  -0.4....................6 items
#    2.  -0.3....................31 items
#    3.  -0.2....................25 items
#    4.  -0.1....................35 items
#    5.  0.0.....................60 items
#    6.  0.1.....................18 items
#    7.  0.2.....................23 items
#    8.  0.3.....................7 items
#    9.  0.4.....................8 items
#   10.  0.5.....................12 items
#   11.  0.6.....................1 items
#   12.  0.7.....................3 items
#   13.  0.8.....................1 items
#   14.  0.9.....................3 items
#   15.  1.1.....................1 items
#   16.  1.8.....................1 items
#   17.  2.4.....................1 items
#   18.  2.8.....................1 items
#   19.  5.6.....................2 items
#
# [beamswitching_vert_angle]:
#    1.  -1.5....................12 items
#    2.  -0.6....................12 items
#    3.  0.0.....................12 items
#    4.  0.9.....................12 items
#    5.  1.5.....................3 items
#    6.  1.6.....................6 items
#    7.  1.7.....................11 items
#    8.  1.8.....................3 items
#    9.  2.6.....................1 items
#   10.  3.6.....................12 items
#   11.  4.4.....................7 items
#   12.  4.5.....................5 items
#   13.  4.6.....................1 items
#   14.  5.3.....................12 items
#   15.  5.5.....................1 items
#   16.  5.8.....................1 items
#   17.  5.9.....................9 items
#   18.  6.0.....................12 items
#   19.  6.1.....................5 items
#   20.  6.3.....................6 items
#   21.  6.8.....................9 items
#   22.  6.9.....................3 items
#   23.  7.5.....................12 items
#   24.  8.0.....................1 items
#   25.  8.8.....................12 items
#   26.  9.5.....................17 items
#   27.  9.6.....................6 items
#   28.  10.1....................3 items
#   29.  10.3....................9 items
#   30.  10.9....................12 items
#   31.  11.6....................12 items

# %%
generator.generate(os.path.abspath('.\output'))
# Out:
# ===============================================================
# Scenario > Virutal port > Virutal band > Pattern assignments
# ===============================================================
# {
#   "7to3 or 4to1-Scenario0": {
#     "uid": "2",
#     "name": "7to3 or 4to1-Scenario0",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario0": {
#         "uid": "3",
#         "name": "7to3 or 4to1-Scenario0",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario0_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario0_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79095,
#                   "vert_angle": 5.49207,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario1": {
#     "uid": "4",
#     "name": "7to3 or 4to1-Scenario1",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario1": {
#         "uid": "5",
#         "name": "7to3 or 4to1-Scenario1",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario1_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario1_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80338,
#                   "vert_angle": 5.49879,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario2": {
#     "uid": "6",
#     "name": "7to3 or 4to1-Scenario2",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario2": {
#         "uid": "7",
#         "name": "7to3 or 4to1-Scenario2",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario2_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario2_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79755,
#                   "vert_angle": 5.49489,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario3": {
#     "uid": "8",
#     "name": "7to3 or 4to1-Scenario3",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario3": {
#         "uid": "9",
#         "name": "7to3 or 4to1-Scenario3",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario3_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario3_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79238,
#                   "vert_angle": 5.5068,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario4": {
#     "uid": "10",
#     "name": "7to3 or 4to1-Scenario4",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario4": {
#         "uid": "11",
#         "name": "7to3 or 4to1-Scenario4",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario4_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario4_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80462,
#                   "vert_angle": 5.4918,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario5": {
#     "uid": "12",
#     "name": "7to3 or 4to1-Scenario5",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario5": {
#         "uid": "13",
#         "name": "7to3 or 4to1-Scenario5",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario5_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario5_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80684,
#                   "vert_angle": 5.49196,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario12": {
#     "uid": "14",
#     "name": "7to3 or 4to1-Scenario12",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario12": {
#         "uid": "15",
#         "name": "7to3 or 4to1-Scenario12",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario12_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79238,
#                   "vert_angle": 5.49479,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario13": {
#     "uid": "16",
#     "name": "7to3 or 4to1-Scenario13",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario13": {
#         "uid": "17",
#         "name": "7to3 or 4to1-Scenario13",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario13_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79869,
#                   "vert_angle": 5.49609,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario14": {
#     "uid": "18",
#     "name": "7to3 or 4to1-Scenario14",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario14": {
#         "uid": "19",
#         "name": "7to3 or 4to1-Scenario14",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario14_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79828,
#                   "vert_angle": 5.49915,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario15": {
#     "uid": "20",
#     "name": "7to3 or 4to1-Scenario15",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario15": {
#         "uid": "21",
#         "name": "7to3 or 4to1-Scenario15",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario15_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80695,
#                   "vert_angle": 5.49244,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario16": {
#     "uid": "22",
#     "name": "7to3 or 4to1-Scenario16",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario16": {
#         "uid": "23",
#         "name": "7to3 or 4to1-Scenario16",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario16_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79115,
#                   "vert_angle": 5.49398,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario10": {
#     "uid": "24",
#     "name": "7to3 or 4to1-Scenario10",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario10": {
#         "uid": "25",
#         "name": "7to3 or 4to1-Scenario10",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario10_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario10_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario10_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80625,
#                   "vert_angle": 5.49185,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario11": {
#     "uid": "26",
#     "name": "7to3 or 4to1-Scenario11",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario11": {
#         "uid": "27",
#         "name": "7to3 or 4to1-Scenario11",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario11_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario11_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario11_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79411,
#                   "vert_angle": 5.49195,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario6": {
#     "uid": "28",
#     "name": "7to3 or 4to1-Scenario6",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario6": {
#         "uid": "29",
#         "name": "7to3 or 4to1-Scenario6",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario6_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario6_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario6_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80777,
#                   "vert_angle": 5.49591,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario7": {
#     "uid": "30",
#     "name": "7to3 or 4to1-Scenario7",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario7": {
#         "uid": "31",
#         "name": "7to3 or 4to1-Scenario7",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario7_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario7_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario7_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80771,
#                   "vert_angle": 5.49675,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario8": {
#     "uid": "32",
#     "name": "7to3 or 4to1-Scenario8",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario8": {
#         "uid": "33",
#         "name": "7to3 or 4to1-Scenario8",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario8_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario8_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario8_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.793,
#                   "vert_angle": 5.50341,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "7to3 or 4to1-Scenario9": {
#     "uid": "34",
#     "name": "7to3 or 4to1-Scenario9",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "7to3 or 4to1-Scenario9": {
#         "uid": "35",
#         "name": "7to3 or 4to1-Scenario9",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario9_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario9_4to1or7to3",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario9_4to1or7to3"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80277,
#                   "vert_angle": 5.49014,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario0": {
#     "uid": "36",
#     "name": "8to2-Scenario0",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario0": {
#         "uid": "37",
#         "name": "8to2-Scenario0",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario0_8to2",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario0_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79034,
#                   "vert_angle": 5.50289,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario1": {
#     "uid": "38",
#     "name": "8to2-Scenario1",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario1": {
#         "uid": "39",
#         "name": "8to2-Scenario1",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario1_8to2",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario1_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79499,
#                   "vert_angle": 5.49678,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario2": {
#     "uid": "40",
#     "name": "8to2-Scenario2",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario2": {
#         "uid": "41",
#         "name": "8to2-Scenario2",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario2_8to2",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario2_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80944,
#                   "vert_angle": 5.49058,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario3": {
#     "uid": "42",
#     "name": "8to2-Scenario3",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario3": {
#         "uid": "43",
#         "name": "8to2-Scenario3",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario3_8to2",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario3_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79617,
#                   "vert_angle": 5.49062,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario4": {
#     "uid": "44",
#     "name": "8to2-Scenario4",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario4": {
#         "uid": "45",
#         "name": "8to2-Scenario4",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario4_8to2",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario4_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79993,
#                   "vert_angle": 5.5022,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario5": {
#     "uid": "46",
#     "name": "8to2-Scenario5",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario5": {
#         "uid": "47",
#         "name": "8to2-Scenario5",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_-1T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_-2T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_01T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_02T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_04T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_05T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_07T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_08T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_10T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_11T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_12T_SSB_Scenario5_8to2",
#               "AAU5635M_3500_X_CO_P45_13T_SSB_Scenario5_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80986,
#                   "vert_angle": 5.49062,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario12": {
#     "uid": "48",
#     "name": "8to2-Scenario12",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario12": {
#         "uid": "49",
#         "name": "8to2-Scenario12",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario12_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79649,
#                   "vert_angle": 5.49603,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario13": {
#     "uid": "50",
#     "name": "8to2-Scenario13",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario13": {
#         "uid": "51",
#         "name": "8to2-Scenario13",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario13_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80786,
#                   "vert_angle": 5.49075,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario14": {
#     "uid": "52",
#     "name": "8to2-Scenario14",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario14": {
#         "uid": "53",
#         "name": "8to2-Scenario14",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario14_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79503,
#                   "vert_angle": 5.49295,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario15": {
#     "uid": "54",
#     "name": "8to2-Scenario15",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario15": {
#         "uid": "55",
#         "name": "8to2-Scenario15",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario15_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79066,
#                   "vert_angle": 5.49279,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario16": {
#     "uid": "56",
#     "name": "8to2-Scenario16",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario16": {
#         "uid": "57",
#         "name": "8to2-Scenario16",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_00T_SSB_Scenario16_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79647,
#                   "vert_angle": 5.49649,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario10": {
#     "uid": "58",
#     "name": "8to2-Scenario10",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario10": {
#         "uid": "59",
#         "name": "8to2-Scenario10",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario10_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario10_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario10_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79063,
#                   "vert_angle": 5.50578,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario11": {
#     "uid": "60",
#     "name": "8to2-Scenario11",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario11": {
#         "uid": "61",
#         "name": "8to2-Scenario11",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario11_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario11_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario11_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79395,
#                   "vert_angle": 5.49035,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario6": {
#     "uid": "62",
#     "name": "8to2-Scenario6",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario6": {
#         "uid": "63",
#         "name": "8to2-Scenario6",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario6_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario6_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario6_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79588,
#                   "vert_angle": 5.49091,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario7": {
#     "uid": "64",
#     "name": "8to2-Scenario7",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario7": {
#         "uid": "65",
#         "name": "8to2-Scenario7",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario7_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario7_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario7_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.79926,
#                   "vert_angle": 5.49626,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario8": {
#     "uid": "66",
#     "name": "8to2-Scenario8",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario8": {
#         "uid": "67",
#         "name": "8to2-Scenario8",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario8_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario8_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario8_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80323,
#                   "vert_angle": 5.49808,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   },
#   "8to2-Scenario9": {
#     "uid": "68",
#     "name": "8to2-Scenario9",
#     "horiz_number_of_elements": 16,
#     "horiz_sep_dist_cm": 0.01,
#     "vert_number_of_elements": 24,
#     "vert_sep_dist_cm": 0.01,
#     "v_ports": {
#       "8to2-Scenario9": {
#         "uid": "69",
#         "name": "8to2-Scenario9",
#         "number_of_ports": 1,
#         "polarization": "Vertical",
#         "polarization_type": null,
#         "v_bands": {
#           "3400-3600": {
#             "min_freq": 3400,
#             "max_freq": 3600,
#             "supp_elec_tilt": true,
#             "supp_elec_azimuth": false,
#             "supp_elec_beamwidth": false,
#             "cont_adj_elec_tilt": false,
#             "broadcast_patterns": [
#               "AAU5635M_3500_X_CO_P45_03T_SSB_Scenario9_8to2",
#               "AAU5635M_3500_X_CO_P45_06T_SSB_Scenario9_8to2",
#               "AAU5635M_3500_X_CO_P45_09T_SSB_Scenario9_8to2"
#             ],
#             "electrical_controller_name": "Controller 1",
#             "use_elec_params_for_bs_service_patterns": true,
#             "beamforming_element_patterns": [],
#             "beamswitching_service_patterns": {
#               "PDSCH": [
#                 {
#                   "horiz_angle": 1.80653,
#                   "vert_angle": 5.50107,
#                   "pattern_name": "AAU5636M_00_X_CO_P45_06T_Traffic"
#                 }
#               ]
#             }
#           }
#         }
#       }
#     },
#     "is_beamswitching": true
#   }
# }
#
# ===============================================================
# The .pafx file was generated successfully
# --> AAU5636m.pafx
# ===============================================================
